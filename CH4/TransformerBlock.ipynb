# %%
# %matplotlib inline

import torch
import torch.nn as nn

import tiktoken
import matplotlib.pyplot as plt


# %load_ext autoreload
# %autoreload 2

from blocks import MultiHeadAttention, FeedForward, LayerNorm, TransformerBlock
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# configuration of the small GPT-2
GPT_CONFIG_124M={
    "vocab_size":50257,       # Vocabulary size
    "context_length":1024,    # Context length
    "emb_dim":768,            # Embedding dimension
    "n_heads":12,             # Number of attention heads
    "n_layers":12,            # Number of layers
    "drop_rate":0.1,          # Dropout rate
    "qkv_bias": False         # Query-key-value bias
}

torch.manual_seed(123)
block=TransformerBlock(GPT_CONFIG_124M)

x=torch.rand(2,4,768) # (batch_size, num_tokens, emb_dim)
output=block(x)
print(f"{x.shape=}, {output.shape}")
# Out:
# x.shape=torch.Size([2, 4, 768]), torch.Size([2, 4, 768])
